# %% [markdown]
# # Predicting The Stanley Cup Champion of 2023

# %% [markdown]
# ## <p style="text-align: right;"> &#9989; Trevor Locknane, Ritik Jain, Jacob Brandt, Lucas Reath</p>

# %%
#imports 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# reading in the csv file made with the stats of NHL teams in the playoffs as of 4/4/2023
df = pd.read_csv('NHL_Standings23.csv', header=0, error_bad_lines=False)
east = df[df['Conference']=='Eastern']
west = df[df['Conference']=='Western']

east.head()
# Out:
#    Rank Conference                 Team  Games Played  Wins  Losses  \
# 0     1    Eastern        Boston Bruins            77    60      12
# 1     2    Eastern  Carolina Hurricanes            76    49      18
# 2     3    Eastern    New Jersey Devils            77    48      21
# 4     5    Eastern     New York Rangers            77    45      21
# 5     6    Eastern  Toronto Maple Leafs            76    45      21
#
#    OT Losses  Points  Points/GP  Goals For  Goals Against  Goal Differential  \
# 0          5     125      1.623        286            166                120
# 1          9     107      1.408        248            196                 52
# 2          8     104      1.351        266            216                 50
# 4         11     101      1.312        261            207                 54
# 5         10     100      1.316        258            211                 47
#
#    GF/GP  GA/GP  GD/GP  Power Play %  Penalty Kill %  Save %
# 0   3.71   2.16  1.558          22.3            86.9   93.12
# 1   3.26   2.58  0.684          20.5            84.0   90.73
# 2   3.45   2.81  0.649          21.4            82.0   90.67
# 4   3.39   2.69  0.701          22.8            80.8   91.22
# 5   3.39   2.78  0.618          25.7            80.5   91.00

# %%
west.head()
# Out:
#    Rank Conference                  Team  Games Played  Wins  Losses  \
# 3     4    Western  Vegas Golden Knights            77    48      22
# 6     7    Western     Los Angeles Kings            77    45      22
# 7     8    Western       Edmonton Oilers            77    45      23
# 8     9    Western          Dallas Stars            77    42      21
# 9    10    Western        Minnesota Wild            77    44      23
#
#    OT Losses  Points  Points/GP  Goals For  Goals Against  Goal Differential  \
# 3          7     103      1.338        257            220                 37
# 6         10     100      1.299        266            242                 24
# 7          9      99      1.286        306            254                 52
# 8         14      98      1.273        267            213                 54
# 9         10      98      1.273        232            209                 23
#
#    GF/GP  GA/GP  GD/GP  Power Play %  Penalty Kill %  Save %
# 3   3.34   2.86  0.481          20.7            77.5   91.43
# 6   3.45   3.14  0.312          25.3            75.7   89.14
# 7   3.97   3.30  0.675          32.4            76.1   90.06
# 8   3.47   2.77  0.701          24.0            83.2   91.48
# 9   3.01   2.71  0.299          21.7            81.3   91.96

# %%
plt.hist(df['Wins'], bins=8)
plt.xlabel('# of wins')
plt.ylabel('# of teams')
plt.title('Distribution of Wins by NHL teams in the playoffs')
plt.grid()
